# %%
# Imports & read files

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns



train = pd.read_csv('train.csv')
test  = pd.read_csv('test.csv')

# %%
# Get NaN counts of each column
# Attributes with NaN can be removed, or replaced by some value
print(len(train))
print(train.isna().sum())
# Out:
# 188533
# id                  0
# brand               0
# model               0
# model_year          0
# milage              0
# fuel_type        5083
# engine              0
# transmission        0
# ext_col             0
# int_col             0
# accident         2452
# clean_title     21419
# price               0
# dtype: int64

# %%
for i in train.columns:
    if not i == 'id':
        print(i, train[i].nunique())
# Out:
# brand 57
# model 1897
# model_year 34
# milage 6651
# fuel_type 7
# engine 1117
# transmission 52
# ext_col 319
# int_col 156
# accident 2
# clean_title 1
# price 1569

# %% [markdown]
# ## Simple qualitative researches & hypotheses on the attributes of attributes.
#
# ### For Brand / Model / Engine:
# 1. Specific model of car can be manufactured by a specific brand(not for the vice versa; one brand can manufacture multiple models). So, if I use the 'Model' feature, probably I don't need the 'Brand' feature. I'll check about it later. (finished: brand feature should be dropped.)
#
# 2. Car price is determined by model and engine, and can't be determined by only one of them. Car price will vary a lot by engine/model when only regressed by model/engine, so I will use joint feature. However, I don't have to use all possible 3M combinations, because there are few engine versions for a single model. I will only consider combinations exist in the train set. But to prevent the case of unseen pair appearing in the test set, I will make separate regressor too. unseen pair will be estimated by this regressor. If completely new model/engine that is not in the train set is shown, I will use the separate regressor and 'blank' encoding. This encoding will also be used when model/engine attribute is blank in the train set, too.
#
# ### For Year:
# 'year' attribute can be target encoded by one column, since each categories are numerically meaningful. New years shown up can be modeled by the same method. Or, I can model quadratic / exponential scoring for how much year has passed from the year shown. Same manipulation can be applied to mileage feature, too.
#
# ### For Color features:
# I don't know if color effects the car price. But public preference on colors exists, and some brands price their cars differently by colors(e.g. Tesla), even if other speculations are exactly the same. This policy can vary brand by brand. So this attribute can be encoded separately or can be paired by brand.
#
# ### For accident:
# 'Yes' and 'At least one' looks same. This can be binary encoded. For the blanks, it can be simply filled or encoded 'blank', but I think there are some possibilities that, car owners didn't want to report because there was an accident. Filling with 'accident happened' can be nice alternative. I need further research for this.
#
# ### For Clean Title:
# Free from legal issue can mean high price. This can be binary encoded.

# %%
duplicate_models = train.groupby('model')['brand'].nunique() > 1

# Filter the models that have multiple brands
models_with_multiple_brands = duplicate_models[duplicate_models].index

# If there are any such cases, print them
if len(models_with_multiple_brands) > 0:
    print("Models produced by different brands:")
    for model in models_with_multiple_brands:
        brands = train[train['model'] == model]['brand'].unique()
        print(f"Model: {model}")
        print(f"Brands: {', '.join(brands)}")
        print()
# Out:
# Models produced by different brands:
# Model: 128 i
# Brands: BMW, FIAT, Chrysler
#
# Model: 135 i
# Brands: BMW, FIAT
#
# Model: 1500 Big Horn
# Brands: RAM, BMW, Ford, Dodge, Chevrolet
#
# Model: 1500 Cheyenne
# Brands: Chevrolet, RAM, Dodge
#
# Model: 1500 Cheyenne Extended Cab
# Brands: Chevrolet, RAM
#
# Model: 1500 Classic SLT
# Brands: RAM, Chevrolet, Lincoln
#
# Model: 1500 Classic Tradesman
# Brands: RAM, Chevrolet
#
# Model: 1500 Laramie
# Brands: RAM, INFINITI, Chevrolet
#
# Model: 1500 Limited
# Brands: RAM, Chevrolet
#
# Model: 1500 Longhorn
# Brands: RAM, Chevrolet
#
# Model: 1500 Rebel
# Brands: RAM, Dodge
#
# Model: 1500 SLT
# Brands: RAM, Chevrolet, Dodge
#
# Model: 1500 Sport
# Brands: RAM, Chevrolet, Dodge
#
# Model: 1500 TRX
# Brands: RAM, Lexus
#
# Model: 200 C
# Brands: Chrysler, Dodge, Subaru
#
# Model: 228 i
# Brands: BMW, Subaru
#
# Model: 240SX Base
# Brands: Nissan, Chevrolet, BMW
#
# Model: 2500 Big Horn
# Brands: RAM, Toyota, Chevrolet, Dodge, BMW, Ford
#
# Model: 2500 Laramie
# Brands: RAM, Lexus, Chevrolet
#
# Model: 2500 SLT
# Brands: RAM, Chevrolet
#
# Model: 2500 Tradesman
# Brands: RAM, Chevrolet, Lexus
#
# Model: 300 Base
# Brands: Chrysler, Lexus, Ford
#
# Model: 300 S
# Brands: Chrysler, Kia, BMW, Nissan
#
# Model: 300 Touring
# Brands: Chrysler, Dodge, BMW, Volvo, Acura
#
# Model: 300C Base
# Brands: Chrysler, Nissan, BMW
#
# Model: 300M Base
# Brands: Chrysler, BMW, Nissan, Ford
#
# Model: 300ZX Base
# Brands: Nissan, Chrysler, Chevrolet, Ford
#
# Model: 320 i xDrive
# Brands: BMW, Audi
#
# Model: 323 Ci
# Brands: Cadillac, BMW, Toyota
#
# Model: 325 Ci
# Brands: Volvo, BMW
#
# Model: 328 i xDrive
# Brands: BMW, Mercedes-Benz, Toyota
#
# Model: 330 330i xDrive
# Brands: BMW, Ford
#
# Model: 330 i
# Brands: BMW, Volkswagen, Porsche
#
# Model: 330 i xDrive
# Brands: BMW, Porsche, Toyota, Acura, Mercedes-Benz
#
# Model: 330e iPerformance
# Brands: BMW, Ford
#
# Model: 335 i
# Brands: BMW, Nissan
#
# Model: 335 is
# Brands: BMW, Acura, Chrysler, INFINITI
#
# Model: 3500 Laramie
# Brands: RAM, Mercedes-Benz, BMW
#
# Model: 3500 Tradesman
# Brands: RAM, Volvo, BMW
#
# Model: 350Z Enthusiast
# Brands: Nissan, Honda, BMW, Kia, Chrysler
#
# Model: 350Z NISMO
# Brands: Nissan, Toyota, BMW
#
# Model: 350Z Touring
# Brands: Nissan, Toyota, Porsche, Ford, Volvo, BMW
#
# Model: 370Z Touring
# Brands: Nissan, BMW, Chevrolet
#
# Model: 428 Gran Coupe i xDrive
# Brands: BMW, Ferrari
#
# Model: 428 i
# Brands: Subaru, BMW
#
# Model: 428 i xDrive SULEV
# Brands: BMW, Ferrari
#
# Model: 430 430i
# Brands: BMW, Nissan
#
# Model: 435 i
# Brands: BMW, Nissan
#
# Model: 440 Gran Coupe 440i xDrive
# Brands: BMW, Mercedes-Benz
#
# Model: 488 GTB Base
# Brands: Ferrari, McLaren, Lamborghini, Jeep, BMW
#
# Model: 488 Spider Base
# Brands: Ferrari, Porsche, BMW, Lamborghini
#
# Model: 4Runner 4WD
# Brands: Toyota, Ford
#
# Model: 4Runner Limited
# Brands: Toyota, BMW, Ford
#
# Model: 4Runner Limited Nightshade
# Brands: Toyota, Lexus
#
# Model: 4Runner SR5
# Brands: Toyota, Honda
#
# Model: 4Runner SR5 Premium
# Brands: Toyota, Lexus, BMW
#
# Model: 4Runner Sport
# Brands: Toyota, Lincoln, Ford
#
# Model: 4Runner TRD Sport
# Brands: Toyota, BMW
#
# Model: 4Runner Venture
# Brands: Toyota, Lexus
#
# Model: 500 Sport
# Brands: Chrysler, FIAT, Nissan
#
# Model: 500X Trekking Plus
# Brands: FIAT, BMW, Ferrari
#
# Model: 500e Battery Electric
# Brands: BMW, FIAT
#
# Model: 528 i xDrive
# Brands: BMW, Porsche, Toyota
#
# Model: 540 i xDrive
# Brands: BMW, Porsche
#
# Model: 550 Gran Turismo i
# Brands: BMW, Ferrari
#
# Model: 570S Base
# Brands: McLaren, BMW
#
# Model: 570S Spider
# Brands: McLaren, Ferrari, Mercedes-Benz, BMW
#
# Model: 640 Gran Coupe i
# Brands: BMW, Volkswagen
#
# Model: 650 i
# Brands: BMW, Nissan, Audi
#
# Model: 718 Boxster GTS
# Brands: Porsche, Ferrari
#
# Model: 718 Cayman GT4
# Brands: Porsche, Mercedes-Benz, Ford
#
# Model: 718 Cayman GTS
# Brands: Porsche, Ferrari
#
# Model: 718 Cayman S
# Brands: Porsche, BMW
#
# Model: 718 Spyder Base
# Brands: Porsche, Ferrari, Audi
#
# Model: 720S Performance
# Brands: McLaren, Porsche
#
# Model: 740 Li
# Brands: BMW, Nissan
#
# Model: 740 i
# Brands: BMW, Porsche
#
# Model: 750 Li xDrive
# Brands: BMW, Audi
#
# Model: 750 i
# Brands: BMW, Audi
#
# Model: 750 i xDrive
# Brands: BMW, Audi, RAM
#
# Model: 750 iL
# Brands: BMW, RAM
#
# Model: 812 Superfast Base
# Brands: Ferrari, Porsche
#
# Model: 86 860 Special Edition
# Brands: Toyota, Mitsubishi
#
# Model: 86 Base
# Brands: Toyota, Porsche, Ferrari
#
# Model: 911 Carrera
# Brands: Porsche, Ford, Aston, Lincoln, Mercedes-Benz, Kia, Hyundai
#
# Model: 911 Carrera 4
# Brands: Porsche, BMW
#
# Model: 911 Carrera 4 GTS
# Brands: Toyota, Porsche, Cadillac, Mercedes-Benz
#
# Model: 911 Carrera 4S
# Brands: Porsche, Volvo, Jaguar
#
# Model: 911 Carrera C4S
# Brands: Porsche, Maserati
#
# Model: 911 Carrera S
# Brands: Porsche, Hyundai, Mercedes-Benz, Ford, Maserati, Mazda, Cadillac, Genesis
#
# Model: 911 GT2 RS
# Brands: Ferrari, Porsche
#
# Model: 911 GT3
# Brands: Porsche, Audi
#
# Model: 911 R
# Brands: Porsche, BMW
#
# Model: 911 Turbo Cabriolet
# Brands: Ford, Porsche
#
# Model: 911 Turbo S
# Brands: Porsche, McLaren, Cadillac, BMW, Mercedes-Benz
#
# Model: A-Class A 220 4MATIC
# Brands: Mercedes-Benz, Audi, Cadillac
#
# Model: A3 2.0 TDI Premium Plus
# Brands: Audi, Ford
#
# Model: A3 2.0T Premium
# Brands: Audi, Mazda, Mercedes-Benz, BMW
#
# Model: A4 2.0T Premium
# Brands: Audi, Cadillac, Mercedes-Benz
#
# Model: A4 2.0T Premium Plus
# Brands: Audi, Ford, Toyota
#
# Model: A4 2.0T Premium quattro
# Brands: Audi, Mercedes-Benz
#
# Model: A4 2.0T Tech Premium
# Brands: Audi, Toyota
#
# Model: A4 2.0T Titanium Premium
# Brands: Audi, BMW
#
# Model: A5 2.0T Premium
# Brands: Audi, Ferrari
#
# Model: A5 2.0T Premium Plus
# Brands: Audi, Mercedes-Benz, Ford
#
# Model: A5 Sportback S line Premium Plus
# Brands: Audi, Kia
#
# Model: A6 2.0T Premium Plus
# Brands: Audi, Porsche, Mercedes-Benz, BMW
#
# Model: A6 3.0 TDI Premium Plus
# Brands: Audi, Mercedes-Benz, Cadillac
#
# Model: A6 3.0T Prestige
# Brands: Audi, Mercedes-Benz
#
# Model: A6 45 Premium Plus
# Brands: Audi, BMW, Mercedes-Benz
#
# Model: A6 55 Premium
# Brands: Audi, Mercedes-Benz, Porsche
#
# Model: A6 55 Premium Plus
# Brands: Audi, Mercedes-Benz
#
# Model: A6 55 Prestige
# Brands: Audi, Mercedes-Benz
#
# Model: A8 L 3.0T
# Brands: Audi, Cadillac
#
# Model: ALPINA B7 ALPINA B7 xDrive
# Brands: BMW, Mercedes-Benz
#
# Model: AMG C 43 AMG C 43 4MATIC
# Brands: Mercedes-Benz, Cadillac
#
# Model: AMG C 43 Base 4MATIC
# Brands: Mercedes-Benz, Lexus
#
# Model: AMG E 53 Base 4MATIC
# Brands: Mercedes-Benz, GMC
#
# Model: AMG E 63 S 4MATIC
# Brands: Mercedes-Benz, BMW, Porsche, Land
#
# Model: AMG G 63 Base
# Brands: Mercedes-Benz, Audi, McLaren, INFINITI
#
# Model: AMG GL AMG GL 63 4MATIC
# Brands: Mercedes-Benz, Audi
#
# Model: AMG GLC 63 Base 4MATIC
# Brands: Mercedes-Benz, Audi
#
# Model: AMG GLE 43 Coupe 4MATIC
# Brands: Mercedes-Benz, Land
#
# Model: AMG GLS 63 4MATIC
# Brands: Mercedes-Benz, BMW
#
# Model: AMG GT 53 Base
# Brands: Mercedes-Benz, Hyundai, Audi, Ford, Porsche, BMW
#
# Model: AMG GT AMG GT S
# Brands: Mercedes-Benz, Porsche
#
# Model: AMG GT C
# Brands: Mercedes-Benz, Porsche
#
# Model: ATS 2.0L Turbo Luxury
# Brands: Cadillac, Acura
#
# Model: ATS 2.5L
# Brands: Cadillac, Mercedes-Benz, Mazda
#
# Model: Acadia Denali
# Brands: GMC, Chevrolet
#
# Model: Acadia SLE
# Brands: GMC, Hyundai, Chevrolet, Mercedes-Benz
#
# Model: Acadia SLE-1
# Brands: GMC, Acura
#
# Model: Acadia SLE-2
# Brands: GMC, Chevrolet
#
# Model: Acadia SLT-1
# Brands: GMC, Mercedes-Benz, Cadillac, Lincoln
#
# Model: Acadia SLT-2
# Brands: GMC, Cadillac
#
# Model: Accent GL
# Brands: Hyundai, Chevrolet, Honda
#
# Model: Accent GLS
# Brands: Hyundai, Nissan, Chevrolet
#
# Model: Accent SEL
# Brands: Hyundai, Kia
#
# Model: Accord Crosstour EX-L
# Brands: Honda, Toyota
#
# Model: Accord EX-L
# Brands: Honda, Toyota
#
# Model: Accord Hybrid Base
# Brands: Honda, Toyota, Lexus
#
# Model: Accord Hybrid Touring
# Brands: Honda, Lexus
#
# Model: Accord Sport
# Brands: Honda, Nissan
#
# Model: Air Grand Touring
# Brands: Lucid, Mercedes-Benz, Audi, Ford, Tesla
#
# Model: Air Pure
# Brands: Acura, Lucid
#
# Model: Altima 2.5 S
# Brands: Nissan, Ford, Subaru
#
# Model: Altima 2.5 SL
# Brands: Nissan, Mazda, Subaru, Lexus
#
# Model: Altima 2.5 SV
# Brands: Nissan, Chevrolet
#
# Model: Armada LE
# Brands: Nissan, Ford, Kia
#
# Model: Arnage R
# Brands: Bentley, Volkswagen, Lincoln
#
# Model: Ascent Touring 7-Passenger
# Brands: Subaru, Nissan, Ford
#
# Model: Atlas 3.6L SE w/Technology
# Brands: Volkswagen, Mercedes-Benz
#
# Model: Atlas Cross Sport 3.6L V6 SEL Premium
# Brands: Volkswagen, Mercedes-Benz
#
# Model: Avalanche 1500 LS
# Brands: Chevrolet, GMC, Lincoln, Dodge, Cadillac
#
# Model: Avalanche 1500 LT
# Brands: Chevrolet, Cadillac
#
# Model: Avalanche 1500 LTZ
# Brands: Chevrolet, BMW
#
# Model: Avalon Limited
# Brands: Toyota, Lexus
#
# Model: Avalon Touring
# Brands: Toyota, Nissan, Subaru
#
# Model: Avenger SE
# Brands: Dodge, Chrysler, Ford
#
# Model: Aventador LP750-4 Superveloce
# Brands: Lamborghini, Maserati
#
# Model: Aventador SVJ Base
# Brands: Lamborghini, Audi
#
# Model: BRZ Limited
# Brands: Subaru, Toyota, Volkswagen
#
# Model: BRZ Premium
# Brands: Subaru, BMW
#
# Model: Baja Base
# Brands: Subaru, Nissan
#
# Model: Bentayga Azure First Edition
# Brands: Bentley, Porsche
#
# Model: Bentayga Onyx Edition
# Brands: Bentley, Mercedes-Benz
#
# Model: Bentayga S
# Brands: Bentley, Aston
#
# Model: Bentayga Speed
# Brands: Bentley, Porsche
#
# Model: Bentayga V8
# Brands: Bentley, Aston
#
# Model: Blazer 1LT
# Brands: Chevrolet, Nissan
#
# Model: Bolt EUV Premier
# Brands: Chevrolet, Toyota, GMC
#
# Model: Bolt EV LT
# Brands: Chevrolet, Kia
#
# Model: Boxster Base
# Brands: Porsche, Mercedes-Benz, Subaru, Nissan, Toyota, Hyundai
#
# Model: Boxster Black Edition
# Brands: Porsche, INFINITI
#
# Model: Boxster S
# Brands: Porsche, Volvo, Nissan
#
# Model: Bronco Badlands Advanced
# Brands: Ford, Porsche, Chevrolet, Buick
#
# Model: Bronco Big Bend Advanced
# Brands: Ford, Porsche, Nissan
#
# Model: Bronco Outer Banks Advanced
# Brands: Ford, Volkswagen, Porsche
#
# Model: Bronco Raptor
# Brands: Ford, Chevrolet
#
# Model: Bronco Sport Big Bend
# Brands: Ford, Mazda
#
# Model: Bronco Wildtrak Advanced
# Brands: Porsche, Ford, Chevrolet
#
# Model: C-Class C 250 Luxury
# Brands: Mercedes-Benz, Cadillac
#
# Model: C-Class C 250 Sport
# Brands: Mercedes-Benz, Volvo
#
# Model: C-Class C 300 4MATIC
# Brands: Mercedes-Benz, Chevrolet, Scion
#
# Model: C-Class C 300 4MATIC Sport
# Brands: Mercedes-Benz, BMW, Lexus
#
# Model: C-HR LE
# Brands: Toyota, Audi, Lexus, Mercedes-Benz
#
# Model: C-Max Energi SE
# Brands: Mercedes-Benz, Ford, Nissan, Honda, Toyota
#
# Model: C40 Recharge Pure Electric Twin Ultimate
# Brands: Volvo, Volkswagen
#
# Model: C70 T5
# Brands: Volvo, Chevrolet
#
# Model: CC Sport
# Brands: Volkswagen, Acura
#
# Model: CLA-Class CLA 250
# Brands: Mercedes-Benz, INFINITI
#
# Model: CLK-Class 550
# Brands: Audi, Mercedes-Benz
#
# Model: CLK-Class CLK 350
# Brands: Mercedes-Benz, Acura, Lexus, Honda, Cadillac, Subaru
#
# Model: CR-V EX
# Brands: Honda, Toyota
#
# Model: CR-V EX-L
# Brands: Honda, Toyota, Scion, Hyundai
#
# Model: CR-V Touring
# Brands: Honda, Toyota
#
# Model: CT 200h Premium
# Brands: Cadillac, Lexus, FIAT, Toyota
#
# Model: CT5 Premium Luxury
# Brands: Cadillac, Lexus
#
# Model: CT5-V Blackwing
# Brands: Cadillac, Lexus
#
# Model: CT5-V V-Series
# Brands: Cadillac, Lexus, Chevrolet, Lincoln
#
# Model: CTS 2.0L Turbo Luxury
# Brands: Cadillac, Chevrolet, Mercedes-Benz
#
# Model: CTS 3.6L Luxury
# Brands: Cadillac, Nissan
#
# Model: CTS 3.6L Premium
# Brands: Cadillac, Porsche
#
# Model: CTS Performance
# Brands: Cadillac, Chevrolet
#
# Model: CTS-V Base
# Brands: Cadillac, Toyota
#
# Model: CX-30 Base
# Brands: Mazda, Acura
#
# Model: CX-30 Premium Package
# Brands: Mazda, Toyota
#
# Model: CX-30 Select
# Brands: Mazda, Toyota, Ford
#
# Model: CX-5 Grand Touring
# Brands: Mazda, Lexus, Toyota
#
# Model: CX-5 Touring
# Brands: Mazda, Toyota
#
# Model: CX-7 Grand Touring
# Brands: Mazda, Mercedes-Benz
#
# Model: CX-9 Carbon Edition
# Brands: Mazda, Chevrolet
#
# Model: CX-9 Grand Touring
# Brands: Mazda, Toyota
#
# Model: CX-9 Touring Plus
# Brands: Mazda, Ford
#
# Model: CX-90 Premium
# Brands: Mazda, Volkswagen
#
# Model: Caliber Express
# Brands: Dodge, Ford
#
# Model: Camaro 1SS
# Brands: Chevrolet, Ford, Toyota
#
# Model: Camaro 2LT
# Brands: Chevrolet, Hyundai, Toyota, GMC
#
# Model: Camaro 2SS
# Brands: Chevrolet, Toyota, Porsche, Dodge, Volvo, Lincoln, GMC
#
# Model: Camaro Base
# Brands: Chevrolet, Porsche, Ford
#
# Model: Camaro LT1
# Brands: Chevrolet, Toyota
#
# Model: Camaro ZL1
# Brands: Chevrolet, RAM
#
# Model: Camry Hybrid Base
# Brands: Toyota, Honda
#
# Model: Camry Hybrid XLE
# Brands: Toyota, Lexus, Mercedes-Benz
#
# Model: Camry LE
# Brands: Toyota, Chevrolet
#
# Model: Camry SE
# Brands: Toyota, Nissan
#
# Model: Camry Solara SE
# Brands: Toyota, Porsche
#
# Model: Camry Solara SLE
# Brands: Toyota, Chevrolet, Porsche
#
# Model: Camry Solara SLE V6
# Brands: Toyota, Volvo, Lexus, Chevrolet
#
# Model: Camry XLE
# Brands: Toyota, Mercedes-Benz
#
# Model: Canyon Denali
# Brands: GMC, Chevrolet
#
# Model: Canyon Elevation Standard
# Brands: GMC, Cadillac, Chevrolet
#
# Model: Cascada Base
# Brands: Buick, Chevrolet, Acura
#
# Model: Cayenne AWD
# Brands: Porsche, Audi
#
# Model: Cayenne E-Hybrid S Platinum Edition
# Brands: Porsche, Volkswagen, Ford
#
# Model: Cayman Base
# Brands: Porsche, Audi, Nissan, Lincoln
#
# Model: Celica GT
# Brands: Toyota, Hyundai
#
# Model: Challenger R/T Scat Pack
# Brands: Dodge, Mazda
#
# Model: Challenger SRT Demon
# Brands: Dodge, Porsche
#
# Model: Challenger SRT Hellcat
# Brands: Dodge, BMW, Porsche
#
# Model: Charger Base
# Brands: Dodge, Chrysler, Ford
#
# Model: Charger R/T
# Brands: Dodge, Nissan
#
# Model: Charger SE
# Brands: Dodge, Kia
#
# Model: Civic EX
# Brands: Honda, Hyundai, Chevrolet, Lexus
#
# Model: Civic LX
# Brands: Honda, Ford, Lexus
#
# Model: Civic Sport
# Brands: Honda, Toyota
#
# Model: Clarity Plug-In Hybrid Base
# Brands: Honda, Nissan, Toyota
#
# Model: Colorado Z71
# Brands: Chevrolet, Cadillac
#
# Model: Commander Base
# Brands: Jeep, Chevrolet, Ford
#
# Model: Commander Sport
# Brands: Lexus, Jeep, Chevrolet, Toyota, Land, Dodge, Ford
#
# Model: Compass Limited
# Brands: Jeep, Mercedes-Benz, Honda
#
# Model: Compass Sport
# Brands: Jeep, GMC
#
# Model: Continental GT Base
# Brands: Bentley, Mercedes-Benz, Lincoln, Jeep
#
# Model: Continental GT Speed
# Brands: Bentley, Lincoln
#
# Model: Continental GT V8
# Brands: Bentley, Ford, Lincoln
#
# Model: Continental GT W12
# Brands: Bentley, Land, Dodge
#
# Model: Continental GTC Base
# Brands: Bentley, Jaguar, Lucid
#
# Model: Continental Reserve
# Brands: Lincoln, Bentley, Ford
#
# Model: Cooper S Base
# Brands: MINI, Mazda, Honda
#
# Model: Cooper S Clubman Base
# Brands: MINI, Chevrolet
#
# Model: Corolla CE
# Brands: Toyota, Honda
#
# Model: Corolla LE
# Brands: Toyota, Nissan
#
# Model: Corolla S Plus
# Brands: Chevrolet, Toyota
#
# Model: Corsair Grand Touring
# Brands: Lincoln, Ford
#
# Model: Corsair Standard
# Brands: Lincoln, Rolls-Royce
#
# Model: Corvette Base
# Brands: Chevrolet, Dodge, Bentley, Lincoln, Cadillac, Ford
#
# Model: Corvette Stingray w/1LT
# Brands: Chevrolet, Ferrari, Acura, Porsche
#
# Model: Corvette Stingray w/2LT
# Brands: Chevrolet, Porsche, Volkswagen, Land, Jeep, Chrysler, GMC
#
# Model: Corvette Stingray w/3LT
# Brands: Chevrolet, Porsche, GMC, Ford
#
# Model: Corvette Z06 w/2LZ
# Brands: Chevrolet, Nissan
#
# Model: Countryman Cooper S
# Brands: Mercedes-Benz, MINI
#
# Model: Countryman Cooper S ALL4
# Brands: MINI, Mazda, Ford
#
# Model: Crossfire Limited
# Brands: Chrysler, Porsche, Nissan, Lincoln, Ford, Honda
#
# Model: Crosstrek 2.0i Limited
# Brands: Subaru, Honda
#
# Model: Crosstrek 2.0i Premium
# Brands: Subaru, Toyota, Volkswagen
#
# Model: Crosstrek Premium
# Brands: Subaru, Honda, Nissan, Toyota
#
# Model: Cruze LTZ
# Brands: Chevrolet, GMC
#
# Model: Cube 1.8 S
# Brands: Nissan, Mazda
#
# Model: Cullinan
# Brands: Rolls-Royce, Maserati, Lucid, Bentley, Ford, Nissan
#
# Model: DTS Base
# Brands: Cadillac, Chevrolet
#
# Model: DTS Luxury
# Brands: Cadillac, Ford
#
# Model: DTS Luxury II
# Brands: Cadillac, Ford
#
# Model: Dakota Big Horn/Lone Star
# Brands: Dodge, Jeep, RAM
#
# Model: Dakota SLT
# Brands: Dodge, Jeep
#
# Model: Dakota SLT Quad Cab
# Brands: Dodge, Ford, Nissan
#
# Model: Dakota Sport
# Brands: Dodge, Ford
#
# Model: Dart SE
# Brands: Dodge, BMW
#
# Model: DeVille Base
# Brands: Cadillac, Chevrolet
#
# Model: Durango GT
# Brands: Dodge, Toyota, BMW
#
# Model: Durango R/T
# Brands: Dodge, Ford, Bentley, Cadillac
#
# Model: Durango SRT
# Brands: Dodge, Chevrolet, Ford
#
# Model: Durango SRT 392
# Brands: Dodge, Chevrolet, Ford
#
# Model: E-Class E 350
# Brands: Mercedes-Benz, Lexus
#
# Model: E-Class E 350 4MATIC
# Brands: Mercedes-Benz, Cadillac, Ferrari, INFINITI, Lincoln, BMW
#
# Model: E-Class E 400
# Brands: Mercedes-Benz, Nissan
#
# Model: E-Class E 450 4MATIC
# Brands: Mercedes-Benz, Audi, Hyundai
#
# Model: E-PACE 300 Sport
# Brands: Jaguar, Ford
#
# Model: E-PACE S
# Brands: Jaguar, Mercedes-Benz, Porsche
#
# Model: E150 XLT
# Brands: Ford, Mercedes-Benz
#
# Model: E350 Super Duty Base
# Brands: Ford, RAM
#
# Model: E350 Super Duty XLT
# Brands: Ford, Mercedes-Benz, Cadillac
#
# Model: EQS 450+ Base
# Brands: Mercedes-Benz, Tesla
#
# Model: ES 350 Base
# Brands: Lexus, Subaru, Mercedes-Benz, Acura, Lincoln, Pontiac, Toyota
#
# Model: EV6 GT-Line
# Brands: Kia, Volvo
#
# Model: EV6 Wind
# Brands: Kia, Mercedes-Benz
#
# Model: Eclipse Spyder GT
# Brands: Mitsubishi, Volkswagen, Nissan
#
# Model: Edge SE
# Brands: Ford, Toyota
#
# Model: Edge SEL
# Brands: Ford, Dodge, Cadillac
#
# Model: Edge Sport
# Brands: Ford, Jaguar, Cadillac
#
# Model: Elantra HEV Limited
# Brands: Toyota, Hyundai
#
# Model: Elantra N Base
# Brands: Volkswagen, Hyundai, Toyota
#
# Model: Element EX
# Brands: Honda, Nissan, Toyota, Mitsubishi, Chevrolet
#
# Model: Enclave Avenir
# Brands: Buick, Chevrolet, Lincoln
#
# Model: Enclave Premium
# Brands: Buick, Jeep
#
# Model: Encore GX Essence
# Brands: Buick, Volkswagen
#
# Model: Encore Preferred
# Brands: Ford, Buick, Nissan
#
# Model: Envision Essence
# Brands: Buick, Ford, Toyota
#
# Model: Equinox LT
# Brands: Chevrolet, Buick, Cadillac
#
# Model: Equus Signature
# Brands: Hyundai, BMW, Chevrolet
#
# Model: Escalade ESV Base
# Brands: Cadillac, Ford
#
# Model: Escalade ESV Luxury
# Brands: Cadillac, Chevrolet
#
# Model: Escalade ESV Platinum
# Brands: Cadillac, Chevrolet
#
# Model: Escalade ESV Platinum Edition
# Brands: Cadillac, Ford
#
# Model: Escalade ESV Premium Luxury Platinum
# Brands: Cadillac, Lincoln
#
# Model: Escalade EXT Base
# Brands: Cadillac, Nissan
#
# Model: Escalade Luxury
# Brands: Cadillac, Chevrolet, Ford
#
# Model: Escalade Platinum
# Brands: Cadillac, GMC
#
# Model: Escalade Premium
# Brands: Cadillac, Land, Dodge
#
# Model: Escalade Sport Platinum
# Brands: Cadillac, Ford
#
# Model: Escape SE
# Brands: Ford, Mercedes-Benz, Jeep
#
# Model: Escape XLT
# Brands: Ford, Chevrolet, Lincoln
#
# Model: Eurovan MV
# Brands: Volkswagen, Chevrolet, Nissan
#
# Model: Excursion Limited
# Brands: Ford, RAM, BMW
#
# Model: Excursion Limited 4WD
# Brands: Ford, Mercedes-Benz, Chevrolet
#
# Model: Excursion Limited Ultimate
# Brands: Ford, Chevrolet, Dodge
#
# Model: Expedition Platinum
# Brands: Ford, Lincoln
#
# Model: Expedition Timberline
# Brands: Ford, Lincoln, Lexus
#
# Model: Explorer Limited
# Brands: Ford, Lincoln
#
# Model: Explorer XLT
# Brands: Ford, Cadillac, Lincoln, Nissan, GMC, Chevrolet, Lexus
#
# Model: Express 1500 Base
# Brands: Chevrolet, Buick
#
# Model: Express 1500 Cargo
# Brands: Ford, Chevrolet
#
# Model: Express 1500 Work Van
# Brands: Chevrolet, Toyota
#
# Model: Express 2500 Work Van
# Brands: Chevrolet, Ford, Buick
#
# Model: F-150 Lariat
# Brands: Ford, BMW, Toyota, Jaguar, Land, Nissan
#
# Model: F-150 Lightning LARIAT
# Brands: Ford, Nissan, Mercedes-Benz
#
# Model: F-150 Lightning XLT
# Brands: Ford, Nissan
#
# Model: F-150 Raptor
# Brands: Ford, Lexus, Porsche, Toyota, Nissan
#
# Model: F-150 SVT Raptor
# Brands: Ford, Toyota
#
# Model: F-150 XL
# Brands: Ford, Land, Jaguar
#
# Model: F-150 XLT
# Brands: Ford, Toyota, Mercury, Jaguar, Lexus
#
# Model: F-250 King Ranch
# Brands: Ford, Mercedes-Benz, RAM, Dodge
#
# Model: F-250 LARIAT
# Brands: Ford, BMW, RAM
#
# Model: F-250 Lariat
# Brands: Ford, Chevrolet, Audi, Rolls-Royce, Dodge, Toyota, Jaguar, Jeep
#
# Model: F-250 Platinum
# Brands: Ford, Lincoln, Porsche, Dodge
#
# Model: F-250 XL
# Brands: Ford, Tesla
#
# Model: F-250 XLT
# Brands: Ford, RAM, Chevrolet, Mercedes-Benz, Toyota, Lincoln, Cadillac
#
# Model: F-250 XLT Super Duty
# Brands: Ford, BMW
#
# Model: F-250 XLT SuperCab Super Duty
# Brands: Ford, Toyota
#
# Model: F-350 Platinum
# Brands: Ford, Cadillac, Chevrolet
#
# Model: F-PACE 30t R-Sport
# Brands: Jaguar, Ford
#
# Model: F-PACE S
# Brands: Jaguar, BMW, Toyota
#
# Model: F-PACE SVR
# Brands: Jaguar, Ford, Mercedes-Benz
#
# Model: F-TYPE R
# Brands: Jaguar, Ferrari, McLaren, Ford
#
# Model: F-TYPE S
# Brands: Jaguar, Mercedes-Benz, Ford
#
# Model: F-TYPE S British Design Edition
# Brands: Jaguar, Ford
#
# Model: F430 Berlinetta
# Brands: Ferrari, BMW
#
# Model: FJ Cruiser Base
# Brands: Toyota, Honda, Ford, BMW, Lincoln
#
# Model: FR-S Monogram
# Brands: Scion, Nissan
#
# Model: FX37 Base
# Brands: INFINITI, Ford, Lincoln
#
# Model: Firebird Base
# Brands: Pontiac, Toyota, Porsche, Chevrolet
#
# Model: Firebird Trans Am
# Brands: Pontiac, Chevrolet, Ford
#
# Model: Fit Sport
# Brands: Honda, MINI, Nissan
#
# Model: Flying Spur V8
# Brands: Bentley, Ferrari, Lamborghini
#
# Model: Focus RS Base
# Brands: Ford, Porsche
#
# Model: Forester 2.5 X
# Brands: Subaru, Honda
#
# Model: Forester 2.5i Limited
# Brands: Subaru, Scion, Honda
#
# Model: Forte GT-Line
# Brands: Kia, Nissan, Dodge, Volkswagen
#
# Model: Forte LX
# Brands: Kia, Toyota
#
# Model: Forte LXS
# Brands: Kia, Acura
#
# Model: Frontier SE Crew Cab
# Brands: Ford, Nissan
#
# Model: Frontier SL
# Brands: Nissan, Ford
#
# Model: Frontier SV
# Brands: Nissan, Ford
#
# Model: Fusion Energi Titanium
# Brands: Ford, BMW
#
# Model: Fusion Hybrid SE Hybrid
# Brands: Ford, Nissan
#
# Model: Fusion SE
# Brands: Ford, Audi
#
# Model: G 550 4x4 Squared Base
# Brands: Mercedes-Benz, Genesis
#
# Model: G-Class G 550 4MATIC
# Brands: Mercedes-Benz, Lexus, Porsche
#
# Model: G-Class G 63 AMG
# Brands: Mercedes-Benz, Lexus, INFINITI, Genesis
#
# Model: G35 Base
# Brands: INFINITI, Genesis, Ford, Honda, Lexus
#
# Model: G35 Sport
# Brands: INFINITI, Genesis, Hyundai, Toyota
#
# Model: G37 Journey
# Brands: INFINITI, Kia, Genesis
#
# Model: G37 x
# Brands: INFINITI, Chevrolet, Genesis, Pontiac, Mercedes-Benz
#
# Model: G70 2.0T
# Brands: Genesis, Mercedes-Benz, BMW, Pontiac
#
# Model: G70 3.3T Advanced
# Brands: Genesis, INFINITI, Pontiac
#
# Model: G8 GT
# Brands: Pontiac, Porsche, Volkswagen
#
# Model: G80 3.8
# Brands: Genesis, INFINITI
#
# Model: GL-Class GL 450
# Brands: Mercedes-Benz, Audi, Chevrolet
#
# Model: GL-Class GL 450 4MATIC
# Brands: Mercedes-Benz, Lexus
#
# Model: GL-Class GL 550 4MATIC
# Brands: Mercedes-Benz, Audi
#
# Model: GLC 300 Base
# Brands: Mercedes-Benz, Lexus
#
# Model: GLC 300 Base 4MATIC
# Brands: Mercedes-Benz, Genesis
#
# Model: GLC 300 GLC 300
# Brands: Mercedes-Benz, Lexus, BMW, Genesis, Nissan
#
# Model: GLE 350 Base 4MATIC
# Brands: Mercedes-Benz, Mercury
#
# Model: GLE 350 GLE 350
# Brands: Mercedes-Benz, Lexus
#
# Model: GLE 450 GLE 450
# Brands: Mercedes-Benz, Genesis
#
# Model: GLS 450 Base 4MATIC
# Brands: Mercedes-Benz, Genesis
#
# Model: GLS 550 Base 4MATIC
# Brands: Mercedes-Benz, Lexus
#
# Model: GR Corolla Circuit Edition
# Brands: Toyota, Ford
#
# Model: GR86 Premium
# Brands: Toyota, Mercedes-Benz, Subaru, Lexus, Ford
#
# Model: GS 350 Base
# Brands: Lexus, Mercedes-Benz, INFINITI
#
# Model: GS 350 F Sport
# Brands: Lexus, Nissan
#
# Model: GT
# Brands: Ford, Nissan, BMW, Porsche, Acura, Audi, Chevrolet, Pontiac, Volkswagen
#
# Model: GT-R Black Edition
# Brands: Nissan, Volkswagen
#
# Model: GT-R Premium
# Brands: Nissan, Ford, Porsche, Ferrari, Mercedes-Benz, BMW
#
# Model: GTC4Lusso T
# Brands: Ferrari, Maserati
#
# Model: GTI Base
# Brands: Volkswagen, Pontiac, Nissan, Lexus, Ford
#
# Model: GTO Base
# Brands: Pontiac, Ferrari, Lamborghini, Ford
#
# Model: GX 460 Base
# Brands: Lexus, Ford, Pontiac, INFINITI, Genesis
#
# Model: GX 460 Luxury
# Brands: Lexus, GMC, Mercedes-Benz
#
# Model: GX 460 Premium
# Brands: Lexus, RAM, Hyundai, Ford
#
# Model: GX 470 Base
# Brands: Lexus, Nissan, INFINITI, Mercedes-Benz, Dodge, Cadillac, Ford
#
# Model: Gallardo LP570-4 Superleggera
# Brands: Lamborghini, Lexus
#
# Model: Gallardo SE
# Brands: Lamborghini, Mercedes-Benz
#
# Model: Genesis 3.8
# Brands: Hyundai, Kia, Nissan
#
# Model: Genesis Coupe 3.8 Track
# Brands: Hyundai, Volkswagen, Kia, Nissan
#
# Model: Ghibli S GranLusso
# Brands: Maserati, Dodge
#
# Model: Ghibli S Q4 GranSport
# Brands: Maserati, Lamborghini
#
# Model: Ghost Base
# Brands: Rolls-Royce, Mercedes-Benz
#
# Model: Gladiator Freedom
# Brands: Jeep, Toyota
#
# Model: Gladiator Overland
# Brands: Jeep, Chevrolet, Lexus
#
# Model: Gladiator Rubicon
# Brands: Jeep, Chevrolet
#
# Model: Gladiator Sport S
# Brands: Jeep, Dodge, Mercedes-Benz, Chevrolet
#
# Model: Golf Auto TSI S
# Brands: Volkswagen, Volvo
#
# Model: Golf GTI 2.0T SE 4-Door
# Brands: Volkswagen, BMW, Jeep, Lincoln
#
# Model: Golf GTI 2.0T SE w/Performance Package 4-Door
# Brands: Volkswagen, Mazda
#
# Model: Golf R 4-Door
# Brands: Volkswagen, Mazda
#
# Model: Golf R 4-Door w/DCC & Navigation
# Brands: Volkswagen, Porsche
#
# Model: Golf R Base
# Brands: Volkswagen, Buick
#
# Model: GranTurismo Base
# Brands: Maserati, Ford, Audi, Porsche, Mercedes-Benz
#
# Model: GranTurismo MC
# Brands: Maserati, Lamborghini, BMW
#
# Model: GranTurismo Sport
# Brands: Maserati, BMW, Audi, Ford
#
# Model: Grand Caravan SE
# Brands: Dodge, Ford
#
# Model: Grand Cherokee L Laredo
# Brands: Jeep, Toyota, Dodge, Ford
#
# Model: Grand Cherokee L Limited
# Brands: Jeep, GMC, Chevrolet
#
# Model: Grand Cherokee L Overland
# Brands: Chevrolet, Jeep
#
# Model: Grand Cherokee Laredo
# Brands: Jeep, GMC
#
# Model: Grand Cherokee Limited
# Brands: Jeep, GMC, Dodge, Buick
#
# Model: Grand Cherokee Summit
# Brands: Dodge, Jeep
#
# Model: Grand Cherokee WK Laredo X
# Brands: Jeep, Chrysler
#
# Model: Grand Wagoneer Base
# Brands: Jeep, RAM
#
# Model: Grand Wagoneer Series III
# Brands: Jeep, Toyota, RAM
#
# Model: Grecale Modena
# Brands: Maserati, Mercedes-Benz, Genesis
#
# Model: H2 Base
# Brands: Hummer, Toyota
#
# Model: H3 Base
# Brands: Hummer, Hyundai, Toyota, Subaru
#
# Model: HS 250h Premium
# Brands: Lexus, Buick
#
# Model: Hardtop Cooper S
# Brands: MINI, Mercedes-Benz, Honda
#
# Model: Highlander Hybrid Limited Platinum
# Brands: Toyota, Lexus, Ford
#
# Model: Highlander Hybrid XLE
# Brands: Toyota, Lexus
#
# Model: Highlander LE Plus
# Brands: Toyota, Ford
#
# Model: Highlander Limited
# Brands: Toyota, Lexus
#
# Model: Highlander XLE
# Brands: Toyota, Nissan, Honda
#
# Model: Huracan EVO Base
# Brands: Lamborghini, Audi, Aston, Jeep
#
# Model: Huracan LP580-2S
# Brands: Lamborghini, Ferrari, Bentley
#
# Model: Huracan Tecnica Coupe
# Brands: Ferrari, Lamborghini, Aston
#
# Model: ILX 2.0L w/Premium Package
# Brands: Acura, Ford, BMW
#
# Model: ILX Premium Package
# Brands: Acura, Subaru
#
# Model: IS 250 Base
# Brands: Lexus, INFINITI, Cadillac, Toyota
#
# Model: IS 300 Base
# Brands: Lexus, Ford
#
# Model: IS 350 Base
# Brands: Lexus, Acura, Honda, Toyota
#
# Model: IS-F Base
# Brands: Lexus, Ford
#
# Model: Impala 1LT
# Brands: Chevrolet, Buick
#
# Model: Impala 2LZ
# Brands: Chevrolet, Ford
#
# Model: Impreza 2.0i
# Brands: Subaru, Ford, Mazda
#
# Model: Impreza 2.0i Premium
# Brands: Subaru, Nissan, Toyota
#
# Model: Impreza 2.0i Sport
# Brands: Subaru, Mitsubishi
#
# Model: Impreza WRX STI
# Brands: Subaru, Honda
#
# Model: Impreza WRX Sti
# Brands: Subaru, Nissan
#
# Model: Integra LS
# Brands: Acura, Lexus, Chevrolet
#
# Model: Jetta 1.4T SE
# Brands: Volkswagen, Kia, Ford
#
# Model: Jetta GLI
# Brands: Volkswagen, Mercedes-Benz
#
# Model: Jetta SportWagen SE
# Brands: Volkswagen, Jeep
#
# Model: Juke NISMO RS
# Brands: Nissan, Jeep
#
# Model: Juke SL
# Brands: Nissan, Lincoln, Ford, Suzuki
#
# Model: Juke SV
# Brands: Nissan, Ford
#
# Model: Kicks S
# Brands: Nissan, Hyundai, Kia
#
# Model: Kona EV SEL
# Brands: Hyundai, Ford, Porsche, Mercedes-Benz, Lincoln
#
# Model: Kona N Base
# Brands: Hyundai, Kia
#
# Model: LC 500 Base
# Brands: Lexus, Toyota, Ford, Mercedes-Benz
#
# Model: LS 430 Base
# Brands: Lexus, Lincoln, Toyota, Chevrolet
#
# Model: LS 460 Base
# Brands: Lexus, Acura, Land
#
# Model: LS 460 Crafted Line
# Brands: Lexus, Toyota
#
# Model: LS 460 L
# Brands: Lexus, Lincoln, Chevrolet
#
# Model: LS V8
# Brands: Lincoln, Lexus
#
# Model: LX 600 F SPORT
# Brands: Lexus, BMW, Mercedes-Benz
#
# Model: LaCrosse Leather
# Brands: Buick, Chevrolet
#
# Model: Lancer Evolution Base
# Brands: Mitsubishi, Nissan
#
# Model: Lancer Sportback ES
# Brands: Mitsubishi, Nissan
#
# Model: Land Cruiser Base
# Brands: Toyota, BMW, Nissan, Lincoln
#
# Model: Leaf SL
# Brands: Nissan, Volkswagen, Mercedes-Benz, Tesla
#
# Model: Leaf SV PLUS
# Brands: Nissan, Tesla, Kia, Volkswagen
#
# Model: Legacy 2.5 GT spec.B
# Brands: Subaru, Lincoln
#
# Model: Legacy 2.5 i Premium
# Brands: Subaru, Toyota, Nissan, Jeep
#
# Model: Legacy 2.5i Premium
# Brands: Subaru, Toyota
#
# Model: Liberty Limited
# Brands: Jeep, Lincoln, Chevrolet, Chrysler, Ford
#
# Model: Liberty Renegade
# Brands: Jeep, Toyota, Ford, Lincoln
#
# Model: Liberty Sport
# Brands: Jeep, Ford, BMW
#
# Model: Lucerne CXL
# Brands: Mercedes-Benz, Buick, Hyundai
#
# Model: M-Class ML 350 4MATIC
# Brands: Mercedes-Benz, BMW, Nissan, Cadillac
#
# Model: M235 i
# Brands: BMW, INFINITI
#
# Model: M240 i
# Brands: BMW, Lexus, Mercedes-Benz, Nissan
#
# Model: M240 i xDrive
# Brands: BMW, Mercedes-Benz
#
# Model: M3 Base
# Brands: BMW, Ford, Audi, Mercedes-Benz, Porsche, Nissan, Dodge, Tesla
#
# Model: M3 CS
# Brands: BMW, Mercedes-Benz, Nissan, Maserati
#
# Model: M3 Competition
# Brands: BMW, Porsche
#
# Model: M3 Competition xDrive
# Brands: BMW, Mercedes-Benz, Ferrari
#
# Model: M340 i xDrive
# Brands: BMW, Mercedes-Benz
#
# Model: M4 Base
# Brands: BMW, Toyota, Audi, Ford, Pontiac, Porsche, Mercedes-Benz, Chrysler
#
# Model: M4 Competition xDrive
# Brands: BMW, Mercedes-Benz
#
# Model: M440 i xDrive
# Brands: BMW, Mercedes-Benz, INFINITI
#
# Model: M5 Base
# Brands: BMW, Porsche, Volvo
#
# Model: M550 i xDrive
# Brands: BMW, Mercedes-Benz
#
# Model: M56 Base
# Brands: INFINITI, Dodge, BMW
#
# Model: M6 Base
# Brands: BMW, Porsche, Audi, Ferrari
#
# Model: M760 i xDrive
# Brands: BMW, Mercedes-Benz
#
# Model: M8 Gran Coupe Competition
# Brands: BMW, Mercedes-Benz
#
# Model: M850 i xDrive
# Brands: BMW, INFINITI
#
# Model: MC20 Base
# Brands: Maserati, BMW, Lamborghini
#
# Model: MDX 3.5L Technology Package
# Brands: Acura, INFINITI
#
# Model: MDX 3.7L Advance
# Brands: Acura, Cadillac
#
# Model: MDX Sport Hybrid 3.0L w/Technology Package
# Brands: Acura, Mercedes-Benz
#
# Model: MDX Technology
# Brands: Acura, Jeep
#
# Model: MDX Touring
# Brands: Acura, Cadillac
#
# Model: MKC Select
# Brands: Lincoln, Nissan
#
# Model: MKX Base
# Brands: Lincoln, Lexus
#
# Model: MKX Reserve
# Brands: Mercedes-Benz, Lincoln
#
# Model: MKZ Base
# Brands: Lincoln, Dodge
#
# Model: MKZ Hybrid Base
# Brands: Lincoln, Mercedes-Benz
#
# Model: MX-5 Miata Base
# Brands: Mazda, Nissan, BMW, Toyota
#
# Model: MX-5 Miata Grand Touring
# Brands: Mazda, Nissan
#
# Model: MX-5 Miata Shinsen
# Brands: Mazda, Ford
#
# Model: Macan
# Brands: Porsche, Mercedes-Benz
#
# Model: Macan Base
# Brands: Porsche, Volkswagen, Mercedes-Benz
#
# Model: Macan GTS
# Brands: Porsche, Audi
#
# Model: Macan S
# Brands: Porsche, Volkswagen, Audi, Hyundai, Mercedes-Benz, BMW, Ford
#
# Model: Magnum Base
# Brands: Jeep, Dodge
#
# Model: Malibu 1LT
# Brands: Chevrolet, Toyota
#
# Model: Marauder Base
# Brands: Mercury, Ford, Toyota
#
# Model: Mark LT Base
# Brands: Lincoln, Ford
#
# Model: Martin DBS Superleggera
# Brands: Aston, Audi, BMW, Porsche
#
# Model: Matrix XR
# Brands: Toyota, BMW
#
# Model: Maverick XLT
# Brands: Ford, Nissan
#
# Model: Maxima GLE
# Brands: Nissan, Ford
#
# Model: Maxima SL
# Brands: Nissan, Acura
#
# Model: Maybach S 580 4MATIC
# Brands: Mercedes-Benz, Porsche
#
# Model: Maybach S S 600
# Brands: Mercedes-Benz, Lexus
#
# Model: Mazda3 s Sport
# Brands: Mazda, Ford
#
# Model: Mazda6 iSport VE
# Brands: Mazda, Ford
#
# Model: Metris Base
# Brands: Mercedes-Benz, Porsche
#
# Model: Mirai Limited
# Brands: Nissan, Toyota, Lexus
#
# Model: Model 3 Long Range
# Brands: Tesla, Toyota, Ford, Porsche, BMW
#
# Model: Model 3 Performance
# Brands: Tesla, Porsche, Chevrolet
#
# Model: Model 3 Standard Range Plus
# Brands: Tesla, Toyota
#
# Model: Model S 70D
# Brands: Tesla, Porsche
#
# Model: Model S P100D
# Brands: Tesla, Porsche
#
# Model: Model X Long Range
# Brands: Tesla, Hyundai
#
# Model: Model X Long Range Plus
# Brands: Tesla, Ford
#
# Model: Model X P100D
# Brands: Tesla, Ford
#
# Model: Model X Performance
# Brands: Tesla, Mercedes-Benz, Ford
#
# Model: Model X Plaid
# Brands: Tesla, Chevrolet
#
# Model: Model Y Long Range
# Brands: Tesla, Dodge, Cadillac, Porsche, Nissan, BMW, Audi, Ford, Rivian
#
# Model: Model Y Performance
# Brands: Tesla, Nissan, Chevrolet, Volvo, Mercedes-Benz, Porsche, Audi
#
# Model: Monte Carlo SS
# Brands: Chevrolet, Buick, Dodge
#
# Model: Monte Carlo Supercharged SS
# Brands: Chevrolet, Ferrari
#
# Model: Montero Limited
# Brands: Mitsubishi, Mazda, Nissan, Ford
#
# Model: Murano SL
# Brands: Nissan, Toyota, Ford, Subaru, Lincoln
#
# Model: Murcielago Base
# Brands: Lamborghini, Nissan
#
# Model: Mustang Base
# Brands: Ford, Porsche
#
# Model: Mustang GT
# Brands: Ford, Chevrolet
#
# Model: Mustang GT Premium
# Brands: Ford, Jaguar, Nissan, BMW, Lincoln, Audi, Porsche, Mazda
#
# Model: Mustang Mach-E GT
# Brands: Ford, Porsche, Audi
#
# Model: Mustang Mach-E Premium
# Brands: Ford, Tesla
#
# Model: Mustang Premium
# Brands: Ford, Nissan, Toyota, Lincoln, Chevrolet
#
# Model: Mustang V6 Premium
# Brands: Ford, Nissan
#
# Model: NSX Base
# Brands: Acura, Toyota, Mercedes-Benz
#
# Model: NV200 S
# Brands: Nissan, Toyota
#
# Model: NX 300 Base
# Brands: Lexus, Toyota
#
# Model: Nautilus Reserve
# Brands: Lincoln, smart, Nissan
#
# Model: Navigator Base
# Brands: Lincoln, Land
#
# Model: Navigator L Reserve
# Brands: Lincoln, Ford
#
# Model: Navigator Reserve
# Brands: Lincoln, Nissan, Ford, Chevrolet
#
# Model: Navigator Select
# Brands: Lincoln, Lexus, Chevrolet
#
# Model: New Beetle GLS
# Brands: Nissan, Volkswagen
#
# Model: Niro EX
# Brands: Kia, Nissan
#
# Model: Niro Plug-In Hybrid EX Premium
# Brands: Kia, Nissan
#
# Model: Odyssey EX-L
# Brands: Honda, Hyundai
#
# Model: Odyssey LX
# Brands: Honda, Nissan
#
# Model: Optima EX
# Brands: Kia, Buick, Hyundai
#
# Model: Optima Hybrid EX
# Brands: Kia, BMW, Nissan, INFINITI
#
# Model: Optima LX
# Brands: Kia, Karma, Mitsubishi, Nissan, Porsche
#
# Model: Outback 2.5i Limited
# Brands: Subaru, Ford
#
# Model: Outback 2.5i Premium
# Brands: Subaru, Mitsubishi
#
# Model: Outback 3.6R Touring
# Brands: Subaru, Nissan
#
# Model: Outback Limited XT
# Brands: Subaru, Honda, Toyota
#
# Model: Outback Touring XT
# Brands: Subaru, Chevrolet
#
# Model: Outlander SEL
# Brands: Mitsubishi, Lincoln
#
# Model: Outlander Sport 2.4 SE
# Brands: Mitsubishi, Toyota
#
# Model: Pacifica Launch Edition
# Brands: Chrysler, Jeep
#
# Model: Palisade Calligraphy
# Brands: Hyundai, Jeep
#
# Model: Palisade Limited
# Brands: Hyundai, Jeep
#
# Model: Palisade SEL
# Brands: Hyundai, Nissan, Porsche
#
# Model: Panamera 4
# Brands: Porsche, Mercedes-Benz, Chevrolet
#
# Model: Panamera 4 Edition
# Brands: Porsche, Volkswagen
#
# Model: Panamera Edition
# Brands: Porsche, BMW
#
# Model: Panamera GTS
# Brands: Porsche, BMW
#
# Model: Panamera Platinum Edition
# Brands: Porsche, Ford
#
# Model: Panamera S
# Brands: Porsche, Mercedes-Benz
#
# Model: Panamera Turbo
# Brands: Porsche, BMW
#
# Model: Passat 2.0T SE
# Brands: Volkswagen, Nissan
#
# Model: Passat 2.5 SE
# Brands: Volkswagen, Nissan, Mercedes-Benz
#
# Model: Passport Elite
# Brands: Honda, Mitsubishi, Ford, Nissan
#
# Model: Pathfinder Platinum
# Brands: Nissan, Volkswagen, Subaru
#
# Model: Pathfinder S
# Brands: Nissan, Honda, Toyota
#
# Model: Pathfinder SL
# Brands: Nissan, Honda
#
# Model: Pathfinder Silver
# Brands: Nissan, INFINITI
#
# Model: Phantom
# Brands: Rolls-Royce, Porsche, Ford
#
# Model: Pickup Truck XE
# Brands: Nissan, Ford
#
# Model: Pilot Black Edition
# Brands: Honda, Nissan, Porsche
#
# Model: Pilot EX-L
# Brands: Honda, Ford
#
# Model: Prelude Type SH
# Brands: Honda, Toyota
#
# Model: Prius v Three
# Brands: Toyota, Dodge
#
# Model: ProMaster 2500 High Roof
# Brands: RAM, Chevrolet
#
# Model: ProMaster 2500 Window Van High Roof
# Brands: RAM, Chevrolet
#
# Model: ProMaster 3500 High Roof
# Brands: RAM, Porsche, Kia
#
# Model: Protege DX
# Brands: Chevrolet, Mazda
#
# Model: Q4 e-tron Sportback Premium
# Brands: Audi, Acura
#
# Model: Q5 2.0T Premium
# Brands: Audi, Acura
#
# Model: Q5 2.0T Premium Plus
# Brands: Audi, BMW, Ford, Volkswagen, INFINITI
#
# Model: Q5 Premium
# Brands: Audi, Jaguar
#
# Model: Q5 S line Premium
# Brands: Audi, Jaguar, Porsche
#
# Model: Q5 S line Premium Plus
# Brands: Audi, Ford, Mercedes-Benz, INFINITI, BMW, Volkswagen, Toyota
#
# Model: Q50 3.0t Red Sport 400
# Brands: INFINITI, Mercedes-Benz, Audi
#
# Model: Q50 Hybrid Premium
# Brands: INFINITI, Lexus
#
# Model: Q7 3.0T Prestige
# Brands: Audi, Mercedes-Benz
#
# Model: Q7 55 Prestige
# Brands: Audi, Mercedes-Benz, Jaguar
#
# Model: Q7 Premium Plus
# Brands: Audi, Mercedes-Benz, INFINITI, BMW, Porsche
#
# Model: Q8 55 Premium
# Brands: Audi, Maserati
#
# Model: Q8 55 Premium Plus
# Brands: Audi, INFINITI
#
# Model: QX56 Base
# Brands: INFINITI, Audi
#
# Model: QX60 Base
# Brands: INFINITI, Nissan
#
# Model: QX60 Luxe
# Brands: INFINITI, Kia, Mercedes-Benz
#
# Model: QX70 Base
# Brands: INFINITI, Porsche
#
# Model: QX80 Luxe
# Brands: INFINITI, Nissan
#
# Model: Quattroporte Base
# Brands: Maserati, Mercedes-Benz, Chevrolet
#
# Model: Quattroporte Sport GT
# Brands: Maserati, Chevrolet, Lamborghini
#
# Model: Quest SL
# Brands: Nissan, Toyota, Jeep
#
# Model: R-Class R 350 4MATIC
# Brands: Mercedes-Benz, Lexus, Toyota
#
# Model: R1S Adventure Package
# Brands: Rivian, Toyota, Nissan, Kia, BMW, Dodge, Subaru, Audi, Tesla, Acura
#
# Model: R1S Launch Edition
# Brands: Rivian, Audi, Dodge
#
# Model: R1T Launch Edition
# Brands: Rivian, Tesla
#
# Model: R8 4.2 quattro Spyder
# Brands: Audi, Mercedes-Benz
#
# Model: R8 5.2
# Brands: Audi, Cadillac
#
# Model: R8 5.2 V10 performance
# Brands: Audi, Honda, McLaren, Cadillac, Porsche, Volkswagen
#
# Model: R8 5.2 V10 plus
# Brands: Audi, Chevrolet, Mercedes-Benz, Porsche
#
# Model: R8 Base
# Brands: Audi, Porsche
#
# Model: RAV4 Base
# Brands: Toyota, Mazda, Audi
#
# Model: RC 350 Base
# Brands: Lexus, Lotus, Toyota
#
# Model: RC F Base
# Brands: Lexus, Toyota, Jaguar
#
# Model: RDX Advance Package
# Brands: Acura, Toyota
#
# Model: RDX PMC Edition
# Brands: Acura, Honda, Ford
#
# Model: RS 4 Base
# Brands: Lexus, Audi
#
# Model: RS 5 2.9T
# Brands: Audi, BMW, Acura, Maserati, Lexus
#
# Model: RS 5 4.2
# Brands: Audi, Acura, Lamborghini
#
# Model: RS 7 4.0T
# Brands: Audi, Acura
#
# Model: RS 7 4.0T Performance Prestige
# Brands: Audi, Mercedes-Benz, Acura, Ford
#
# Model: RS 7 4.0T quattro
# Brands: Audi, Mercedes-Benz, Lexus
#
# Model: RS Q8 4.0T
# Brands: Audi, Mercedes-Benz, Acura
#
# Model: RS Q8 4.0T quattro
# Brands: Audi, Mercedes-Benz, Porsche, Acura
#
# Model: RSX Type S
# Brands: Acura, Audi, Lexus, Lincoln
#
# Model: RX 300 4WD
# Brands: Lexus, Ford, Toyota
#
# Model: RX 330 Base
# Brands: Lexus, Chrysler, Nissan
#
# Model: RX 350 Base
# Brands: Lexus, Jaguar, Toyota, Mazda, Acura
#
# Model: RX 350 F SPORT Appearance
# Brands: Lexus, Toyota
#
# Model: RX 350 F Sport
# Brands: Lexus, Toyota, Acura
#
# Model: RX 450h Base
# Brands: Lexus, Toyota, BMW
#
# Model: RX 450h F Sport Handling
# Brands: Ford, Lexus
#
# Model: RX-8 Grand Touring
# Brands: Mazda, Subaru
#
# Model: RX-8 R3
# Brands: Mazda, Toyota, Lexus
#
# Model: RX-8 Sport
# Brands: Mazda, Toyota
#
# Model: Rainier CXL
# Brands: Buick, Porsche
#
# Model: Ram 1500 Laramie Mega Cab
# Brands: Dodge, RAM
#
# Model: Ram 1500 Quad Cab
# Brands: Dodge, Cadillac
#
# Model: Ram 1500 ST
# Brands: Dodge, Toyota, Nissan, RAM, Lincoln
#
# Model: Ram 2500 Laramie Quad Cab
# Brands: Dodge, Chevrolet
#
# Model: Ram 2500 SLT Mega Cab
# Brands: Dodge, BMW, Chevrolet
#
# Model: Ram 2500 ST
# Brands: Dodge, Toyota
#
# Model: Ranger Lariat
# Brands: Ford, Lincoln
#
# Model: Ranger Sport SuperCab
# Brands: Ford, Chevrolet
#
# Model: Ranger XLT
# Brands: Ford, Toyota
#
# Model: Regal Turbo - Premium 1
# Brands: Buick, Mercedes-Benz
#
# Model: Ridgeline RTL-E
# Brands: Acura, Honda, Nissan, Audi, Toyota
#
# Model: Roadmaster Estate
# Brands: Buick, Mercury
#
# Model: Rogue SL
# Brands: Nissan, Volkswagen
#
# Model: Rogue Sport S
# Brands: Nissan, Ford
#
# Model: Roma Base
# Brands: Ferrari, Maserati, Mercedes-Benz, BMW, McLaren
#
# Model: Romeo Giulia Quadrifoglio
# Brands: Alfa, Audi
#
# Model: Romeo Giulia Ti
# Brands: Alfa, Ford, Porsche, Audi
#
# Model: Romeo Stelvio Ti Sport
# Brands: Alfa, Audi
#
# Model: Routan SE
# Brands: Volkswagen, Buick, Dodge
#
# Model: Rover Defender S
# Brands: Land, BMW
#
# Model: Rover Defender SE
# Brands: Land, Nissan, Audi
#
# Model: Rover Discovery HSE
# Brands: Land, Mercedes-Benz
#
# Model: Rover Discovery S
# Brands: Land, Ford
#
# Model: Rover Discovery SE
# Brands: Land, Porsche
#
# Model: Rover Range Rover Evoque Pure
# Brands: Land, Chevrolet
#
# Model: Rover Range Rover Evoque R-Dynamic HSE
# Brands: Land, Subaru
#
# Model: Rover Range Rover Evoque SE
# Brands: Land, Chevrolet
#
# Model: Rover Range Rover P530 SE LWB 7 Seat
# Brands: Land, BMW, Lexus
#
# Model: Rover Range Rover P530 SE SWB
# Brands: Land, BMW
#
# Model: Rover Range Rover SV Autobiography Dynamic SWB
# Brands: Land, Nissan
#
# Model: Rover Range Rover Sport HSE
# Brands: Land, BMW, Jaguar, Ford
#
# Model: Rover Range Rover Sport HST MHEV
# Brands: Land, Porsche
#
# Model: Rover Range Rover Sport SVR
# Brands: Land, Porsche
#
# Model: Rover Range Rover Sport Supercharged
# Brands: Land, BMW
#
# Model: Rover Range Rover Velar R-Dynamic S
# Brands: Land, Jaguar
#
# Model: S-Class S 550 4MATIC
# Brands: Mercedes-Benz, BMW
#
# Model: S-Class S 560 4MATIC
# Brands: Mercedes-Benz, BMW, Kia
#
# Model: S-Class S 580 4MATIC
# Brands: Mercedes-Benz, Audi, INFINITI, Lexus
#
# Model: S-Class S 63 AMG
# Brands: Mercedes-Benz, Audi
#
# Model: S2000 Base
# Brands: Honda, Toyota, Acura
#
# Model: S2000 CR
# Brands: Honda, Toyota, Suzuki, Nissan
#
# Model: S4 Base
# Brands: Audi, Lotus, Porsche, BMW
#
# Model: S40 T5
# Brands: Volvo, Audi, BMW
#
# Model: S5 3.0 Premium Plus
# Brands: Audi, Mercedes-Benz
#
# Model: S60 Recharge Plug-In Hybrid T8 Inscription
# Brands: Volvo, Mercedes-Benz
#
# Model: S60 T6 Momentum
# Brands: Volvo, BMW, Audi
#
# Model: S7 2.9T Prestige
# Brands: Audi, Kia
#
# Model: S8 4.0T Plus
# Brands: Audi, Porsche
#
# Model: S8 4.0T quattro
# Brands: Audi, Mercedes-Benz
#
# Model: S80 3.2
# Brands: Volvo, Acura
#
# Model: SC 300 Base
# Brands: Lexus, Chrysler
#
# Model: SC 430 Base
# Brands: Lexus, Chevrolet, Lincoln
#
# Model: SL-Class SL 550
# Brands: Mercedes-Benz, Audi
#
# Model: SL-Class SL500 Roadster
# Brands: Mercedes-Benz, BMW
#
# Model: SL-Class SL550 Roadster
# Brands: Mercedes-Benz, BMW
#
# Model: SL-Class SL63 AMG Roadster
# Brands: Mercedes-Benz, Lincoln
#
# Model: SLC 300 Base
# Brands: Mercedes-Benz, Kia, Audi, BMW
#
# Model: SLK-Class SLK 350
# Brands: Mercedes-Benz, Cadillac
#
# Model: SLK-Class SLK320
# Brands: Mercedes-Benz, Nissan, Honda, Acura
#
# Model: SQ5 3.0T Premium
# Brands: Audi, Acura
#
# Model: SQ5 3.0T Premium Plus
# Brands: Audi, Mercedes-Benz
#
# Model: SRX Luxury Collection
# Brands: Cadillac, Lexus, Chevrolet
#
# Model: SRX Standard
# Brands: Cadillac, GMC
#
# Model: SSR Base
# Brands: Chevrolet, Pontiac, Mercedes-Benz, Lincoln, GMC
#
# Model: STS V6
# Brands: Chevrolet, Cadillac
#
# Model: SX4 Base
# Brands: Suzuki, BMW, Lexus, Volkswagen
#
# Model: Santa Cruz 2.5T Limited
# Brands: Hyundai, Toyota
#
# Model: Santa Fe SE
# Brands: Hyundai, Toyota
#
# Model: Santa Fe SEL
# Brands: Hyundai, Chevrolet, Toyota, Buick
#
# Model: Savana 2500 Work Van
# Brands: GMC, Ford
#
# Model: Sequoia Limited
# Brands: Toyota, BMW, Dodge, Nissan
#
# Model: Sequoia Platinum
# Brands: Toyota, Mercedes-Benz, GMC, Chevrolet
#
# Model: Sequoia SR5
# Brands: Toyota, RAM, Nissan
#
# Model: Sequoia TRD Pro
# Brands: Toyota, BMW
#
# Model: Shelby GT350 Base
# Brands: Ford, BMW, Mercedes-Benz
#
# Model: Shelby GT350R Base
# Brands: Ford, Nissan
#
# Model: Shelby GT500 Base
# Brands: Ford, Chevrolet, Cadillac, Porsche
#
# Model: Sienna XLE Limited
# Brands: Toyota, Honda
#
# Model: Sierra 1500 Denali
# Brands: GMC, Ford
#
# Model: Sierra 1500 Denali Ultimate
# Brands: GMC, Cadillac, Chevrolet
#
# Model: Sierra 1500 SLE Crew Cab
# Brands: GMC, Chevrolet
#
# Model: Sierra 1500 SLT
# Brands: GMC, Volkswagen
#
# Model: Sierra 2500 AT4
# Brands: GMC, BMW, RAM, Cadillac
#
# Model: Sierra 2500 Base
# Brands: GMC, RAM
#
# Model: Sierra 2500 Denali
# Brands: GMC, Cadillac, Chevrolet
#
# Model: Sierra 2500 SLE H/D Extended Cab
# Brands: GMC, Chevrolet
#
# Model: Silverado 1500 1LT
# Brands: Chevrolet, GMC
#
# Model: Silverado 1500 2LT
# Brands: Chevrolet, Toyota, Hummer, Mercedes-Benz
#
# Model: Silverado 1500 Custom Trail Boss
# Brands: GMC, Chevrolet, Mercedes-Benz
#
# Model: Silverado 1500 LT Extended Cab
# Brands: Chevrolet, Buick
#
# Model: Silverado 1500 LT Trail Boss
# Brands: Chevrolet, Ford
#
# Model: Silverado 1500 LTZ
# Brands: Chevrolet, Dodge
#
# Model: Silverado 1500 Limited Custom
# Brands: Chevrolet, Cadillac
#
# Model: Silverado 1500 Limited LT Trail Boss
# Brands: Chevrolet, Mercedes-Benz
#
# Model: Silverado 1500 RST
# Brands: Chevrolet, Ford
#
# Model: Silverado 1500 W/T
# Brands: Chevrolet, Pontiac
#
# Model: Silverado 1500 Z71 Extended Cab
# Brands: Chevrolet, Ford, Cadillac
#
# Model: Silverado 2500 H/D
# Brands: Chevrolet, Ford
#
# Model: Silverado 2500 LT
# Brands: Chevrolet, Ford
#
# Model: Silverado 2500 WT
# Brands: Chevrolet, Ford, GMC
#
# Model: Silverado 3500 High Country
# Brands: Chevrolet, Dodge
#
# Model: Silverado 3500 LTZ
# Brands: Chevrolet, GMC
#
# Model: Sky Red Line
# Brands: Saturn, Jeep, Nissan, Volkswagen
#
# Model: Solstice GXP
# Brands: Pontiac, Chevrolet, Nissan
#
# Model: Sonata Hybrid Base
# Brands: Hyundai, Lexus
#
# Model: Sonata SE
# Brands: Hyundai, Chevrolet
#
# Model: Sonata Sport 2.0T
# Brands: Hyundai, Kia
#
# Model: Sonic LT
# Brands: Chevrolet, Hyundai
#
# Model: Sorento EX
# Brands: Kia, Honda
#
# Model: Sorento EX V6
# Brands: Kia, Honda
#
# Model: Sorento LX
# Brands: Kia, Honda
#
# Model: Sorento S
# Brands: Kia, Audi
#
# Model: Sorento SX
# Brands: Kia, Hyundai, Honda
#
# Model: Sorento SXL
# Brands: Kia, Acura
#
# Model: Sportage LX
# Brands: Kia, Suzuki, Ford, Jeep, Land, Jaguar, Toyota
#
# Model: Sportage Nightfall
# Brands: Kia, Hyundai
#
# Model: Sportage S
# Brands: Kia, Hyundai
#
# Model: Sportage X-Pro
# Brands: Kia, Ford
#
# Model: Sprinter 2500
# Brands: Mercedes-Benz, Toyota, Dodge, Ford, Volkswagen
#
# Model: Sprinter 2500 High Roof
# Brands: Dodge, Mercedes-Benz, Ford, Audi
#
# Model: Sprinter 2500 Standard Roof
# Brands: Mercedes-Benz, Dodge, BMW, Volkswagen, Toyota
#
# Model: Sprinter 3500 High Roof
# Brands: Mercedes-Benz, Audi
#
# Model: Sprinter 4500 High Roof
# Brands: Mercedes-Benz, Ford
#
# Model: Sprinter High Roof
# Brands: Mercedes-Benz, Kia, Ford, Toyota, Dodge
#
# Model: Stinger GT1
# Brands: Chevrolet, Kia
#
# Model: Suburban 1500 LTZ
# Brands: Chevrolet, Plymouth, Cadillac, Lincoln
#
# Model: Suburban 2500
# Brands: Chevrolet, GMC, RAM
#
# Model: Suburban 2500 LS
# Brands: Chevrolet, GMC
#
# Model: Suburban LT
# Brands: Chevrolet, GMC, Mercury, Mercedes-Benz, Volkswagen
#
# Model: Suburban Premier
# Brands: Chevrolet, Lucid, Cadillac, GMC
#
# Model: Suburban RST
# Brands: Chevrolet, GMC, Dodge, Ford
#
# Model: Supra 3.0 Premium
# Brands: Toyota, Lexus, Nissan
#
# Model: TLX A-Spec
# Brands: Acura, Mercedes-Benz
#
# Model: TLX PMC Edition
# Brands: Acura, Volkswagen
#
# Model: TLX Type S PMC Edition
# Brands: Acura, Kia, INFINITI
#
# Model: TLX V6 Advance
# Brands: Acura, Lexus
#
# Model: TSX Technology
# Brands: Acura, Lexus, Honda
#
# Model: TT 1.8T
# Brands: Audi, BMW
#
# Model: TT 3.2 Cabriolet quattro
# Brands: Audi, BMW
#
# Model: TT Roadster quattro
# Brands: Audi, Volkswagen
#
# Model: TTS 2.0T Premium Plus
# Brands: Audi, Porsche
#
# Model: Tacoma PreRunner
# Brands: Toyota, Honda, Ford, Lexus, Nissan
#
# Model: Tacoma TRD Sport
# Brands: Toyota, BMW
#
# Model: Tahoe High Country
# Brands: Chevrolet, GMC
#
# Model: Tahoe LS
# Brands: Chevrolet, Mercedes-Benz
#
# Model: Tahoe LTZ
# Brands: Chevrolet, Tesla, BMW, GMC
#
# Model: Taurus SHO
# Brands: Ford, Ferrari, Audi, Toyota
#
# Model: Taurus X Limited
# Brands: Ford, Lexus
#
# Model: Taycan 4S
# Brands: Porsche, Audi, Mercedes-Benz
#
# Model: Taycan Base
# Brands: Porsche, Toyota, Volvo, Volkswagen
#
# Model: Telluride S
# Brands: Kia, Mercedes-Benz
#
# Model: Telluride SX
# Brands: Kia, Nissan
#
# Model: Terrain SLE
# Brands: Lexus, GMC, Toyota, Mercedes-Benz
#
# Model: Terrain SLT
# Brands: GMC, Toyota, Chevrolet, Ford
#
# Model: Terrain SLT-1
# Brands: GMC, Toyota, Chevrolet, Lincoln, Hyundai, Buick
#
# Model: Thunderbird Deluxe
# Brands: Ford, Dodge
#
# Model: Thunderbird Premium
# Brands: Ford, Jeep
#
# Model: Tiguan 2.0T SEL Premium R-Line
# Brands: Volkswagen, Jeep
#
# Model: Titan SL
# Brands: Nissan, Hyundai
#
# Model: Titan SV
# Brands: Nissan, Lucid, Ford
#
# Model: Touareg V6 Executive
# Brands: Volkswagen, Porsche
#
# Model: Town & Country Touring-L
# Brands: Chrysler, RAM, Lincoln, Jeep
#
# Model: Town Car Base
# Brands: Lincoln, Chrysler
#
# Model: Town Car Signature
# Brands: Lincoln, Mercedes-Benz
#
# Model: Trailblazer SS
# Brands: Chevrolet, GMC
#
# Model: Transit Connect XLT
# Brands: Ford, Acura
#
# Model: Transit-250 Base
# Brands: Ford, Nissan, Toyota
#
# Model: Transit-350 XLT
# Brands: Ford, Lincoln
#
# Model: Traverse High Country
# Brands: Chevrolet, RAM
#
# Model: Tucson Limited
# Brands: Hyundai, Mazda, Nissan, Chevrolet
#
# Model: Tucson SE
# Brands: Hyundai, Chevrolet, Nissan
#
# Model: Tucson SEL
# Brands: Hyundai, Toyota, Mazda
#
# Model: Tundra Hybrid Capstone
# Brands: Toyota, Ford, Audi
#
# Model: Tundra Hybrid TRD Pro
# Brands: Toyota, Lexus, BMW
#
# Model: Tundra Limited
# Brands: Toyota, Ford
#
# Model: Tundra SR
# Brands: Toyota, BMW
#
# Model: Tundra SR5
# Brands: Toyota, Ford, Pontiac
#
# Model: Tundra SR5 Access Cab
# Brands: Toyota, Ford, Porsche
#
# Model: Type 57 Base
# Brands: Maybach, Pontiac
#
# Model: Urus Base
# Brands: Lamborghini, Ferrari, McLaren, Bentley, Maserati
#
# Model: Urus Pearl Capsule
# Brands: Lamborghini, Bentley
#
# Model: V60 Cross Country T5
# Brands: Volvo, Mercedes-Benz
#
# Model: Veloster Base
# Brands: Hyundai, Mazda, Nissan
#
# Model: Versa 1.8 S
# Brands: Nissan, Honda
#
# Model: Veyron 16.4 Grand Sport
# Brands: Mercedes-Benz, Bugatti, Volkswagen
#
# Model: Viper GTC
# Brands: Dodge, Chevrolet
#
# Model: Vue Hybrid Base
# Brands: Jaguar, Saturn
#
# Model: WRX Base
# Brands: Subaru, Mercedes-Benz, Toyota
#
# Model: WRX Limited
# Brands: Subaru, Toyota, Mercedes-Benz
#
# Model: Wagoneer Series II 4x4
# Brands: Jeep, Acura, Volkswagen
#
# Model: Wagoneer Series III
# Brands: Jeep, Volkswagen
#
# Model: Wraith Base
# Brands: Rolls-Royce, BMW, Bentley, Porsche
#
# Model: Wrangler SE
# Brands: Jeep, Honda
#
# Model: Wrangler Sahara
# Brands: Jeep, Chrysler, Chevrolet, GMC
#
# Model: Wrangler Sport
# Brands: Jeep, Mercedes-Benz, Ford, Toyota, Genesis, Chevrolet, Nissan
#
# Model: Wrangler Unlimited Rubicon
# Brands: Jeep, Chevrolet
#
# Model: Wrangler Unlimited Rubicon 392
# Brands: Jeep, Toyota
#
# Model: Wrangler Unlimited Sahara
# Brands: Jeep, Volkswagen
#
# Model: Wrangler Unlimited X
# Brands: Jeep, Cadillac
#
# Model: Wrangler X
# Brands: Jeep, Nissan, Toyota
#
# Model: X1 sDrive28i
# Brands: BMW, Audi
#
# Model: X1 xDrive28i
# Brands: BMW, Audi
#
# Model: X2 xDrive28i
# Brands: BMW, Volvo
#
# Model: X3 M AWD
# Brands: BMW, Lexus
#
# Model: X4 M Competition
# Brands: BMW, Cadillac
#
# Model: X5 PHEV xDrive45e
# Brands: BMW, Ford
#
# Model: X6 M Base
# Brands: BMW, Lexus
#
# Model: XC70 3.2
# Brands: Volvo, Lexus
#
# Model: XC90 Recharge Plug-In Hybrid T8 Inscription 7 Passenger
# Brands: Volvo, Porsche, Ford
#
# Model: XE 25t
# Brands: Jaguar, Ford
#
# Model: XF 35t Prestige
# Brands: Jaguar, Ford
#
# Model: XF 35t R-Sport
# Brands: Jaguar, Chevrolet
#
# Model: XK8 Base
# Brands: Jaguar, Ford, BMW
#
# Model: XT5 Base
# Brands: Cadillac, Ford
#
# Model: XT5 Luxury
# Brands: Cadillac, Lexus
#
# Model: XTS Luxury
# Brands: Cadillac, Scion, Lexus
#
# Model: XTS Premium
# Brands: Cadillac, Chrysler
#
# Model: Xterra Pro-4X
# Brands: Nissan, Lexus, Audi
#
# Model: Xterra S
# Brands: Nissan, Ford, Audi, Lucid, BMW
#
# Model: Yaris Base
# Brands: Toyota, Nissan
#
# Model: Yaris L
# Brands: Toyota, Scion, Honda
#
# Model: Yukon Denali
# Brands: GMC, Volkswagen, Ford
#
# Model: Yukon Denali Ultimate
# Brands: GMC, Chevrolet
#
# Model: Yukon SLE
# Brands: GMC, Chevrolet, Mercedes-Benz
#
# Model: Yukon SLT
# Brands: GMC, Nissan, Chevrolet
#
# Model: Yukon XL Denali
# Brands: GMC, Chevrolet, Nissan
#
# Model: Yukon XL SLT
# Brands: GMC, Jeep
#
# Model: Z Proto Spec
# Brands: Nissan, Mazda
#
# Model: ZDX Base
# Brands: Acura, Mazda
#
# Model: e-tron Prestige
# Brands: Audi, Volkswagen, Acura
#
# Model: i3 120Ah w/Range Extender
# Brands: BMW, Volkswagen, Audi
#
# Model: i3 Base w/Range Extender
# Brands: BMW, Audi, MINI
#
# Model: i8 Base
# Brands: BMW, Toyota, Volvo, Mercedes-Benz, Hyundai, Kia
#
# Model: tC Release Series 6.0
# Brands: Scion, Toyota

# %% [markdown]
# **Fact** : Some model classification is a mess. for example, '911 carrera' is a Porsche brand, but the data shows Porsche, Ford, Aston, Lincoln, Mercedes-Benz, Kia, Hyundai for the manufacturers of the car. This means brand attribute should be removed to prevent misclassification, and I should use model as a implication of brand.

# %%
print(train['fuel_type'].value_counts().to_string())
# Out:
# Gasoline          165940
# Hybrid              6832
# E85 Flex Fuel       5406
# Diesel              3955
# –                    781
# Plug-In Hybrid       521
# not supported         15

# %%
# Show all rows in train dataframe that has price higher than 1000000
cols = ['brand', 'price', 'model', 'model_year']
print(train[train['price'] > 500000].loc[:, cols].sort_values(by='price', ascending=False))
print(train[train['price'] < 3000])
# Out:
#                 brand    price  \
# 220              Ford  2954083
# 74189   Mercedes-Benz  2954083
# 84731   Mercedes-Benz  2954083
# 67957            Land  2954083
# 129054       INFINITI  2954083
# ...               ...      ...
# 8259             Ford   599000
# 146385        Porsche   599000
# 140896           Ford   599000
# 140089  Mercedes-Benz   599000
# 45305         Porsche   599000
#
#                                                     model  model_year
# 220                                             F-150 XLT        2021
# 74189                                         Metris Base        2020
# 84731                                      AMG GT 53 Base        2023
# 67957   Rover Range Rover 5.0L Supercharged Autobiogra...        2017
# 129054                                          QX60 Base        2017
# ...                                                   ...         ...
# 8259                                      Bronco Big Bend        2021
# 146385                                            911 GT3        2021
# 140896                           Bronco Badlands Advanced        2023
# 140089                               Maybach S 580 4MATIC        2023
# 45305                                        Taycan Turbo        2020
#
# [352 rows x 4 columns]
#             id          brand                      model  model_year  milage  \
# 348        348     Volkswagen                 Eurovan MV        2001  121800
# 456        456           Ford      F-250 XL SuperCab H/D        1997   90400
# 462        462  Mercedes-Benz              Sprinter 2500        2004  158366
# 758        758        Pontiac          Firebird Trans Am        2001  150000
# 1044      1044           Jeep                 Cherokee X        2018   64549
# ...        ...            ...                        ...         ...     ...
# 186854  186854     Volkswagen             New Beetle GLS        2001   46508
# 187603  187603        Hyundai                  Sonata SE        2013   87001
# 187838  187838          Dodge  Ram 1500 Laramie Mega Cab        2010  155000
# 187916  187916       Chrysler                  300C Base        2011  117292
# 188475  188475         Toyota                  Matrix XR        2000  185000
#
#             fuel_type                                             engine  \
# 348          Gasoline      140.0HP 2.8L V6 Cylinder Engine Gasoline Fuel
# 456          Gasoline       220.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 462            Diesel         161.0HP 2.1L 4 Cylinder Engine Diesel Fuel
# 758          Gasoline       310.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 1044    E85 Flex Fuel  220.0HP 2.0L 4 Cylinder Engine Flex Fuel Capab...
# ...               ...                                                ...
# 186854       Gasoline       115.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 187603       Gasoline       200.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 187838       Gasoline       345.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 187916       Gasoline      292.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 188475       Gasoline       130.0HP 1.8L 4 Cylinder Engine Gasoline Fuel
#
#        transmission ext_col int_col                                accident  \
# 348             A/T   Green   Black                           None reported
# 456             A/T     Red    Gray                           None reported
# 462             A/T   White       –  At least 1 accident or damage reported
# 758             A/T   Black   Beige                           None reported
# 1044            A/T   White   Black                                     NaN
# ...             ...     ...     ...                                     ...
# 186854  5-Speed M/T  Silver   Black  At least 1 accident or damage reported
# 187603          A/T   White    Gray  At least 1 accident or damage reported
# 187838          A/T  Silver    Gray  At least 1 accident or damage reported
# 187916  6-Speed A/T   Beige   Beige  At least 1 accident or damage reported
# 188475  4-Speed A/T    Gray       –  At least 1 accident or damage reported
#
#        clean_title  price
# 348            Yes   2300
# 456            Yes   2800
# 462            Yes   2300
# 758            Yes   2000
# 1044           NaN   2899
# ...            ...    ...
# 186854         Yes   2500
# 187603         Yes   2300
# 187838         Yes   2500
# 187916         Yes   2300
# 188475         Yes   2500
#
# [432 rows x 13 columns]

# %% [markdown]
# **Fact** : Some car prices are definitely abnormal. There are not many of them but can make crucial consequences if the anomaly is huge. For example, brand new Ford F-150 XLT in the first row is sold around $70k according to the internet, and this data is telling me that same model used for 2 years is sold at almost $3M, which is more than 40 times higher than the new one. I need more research to balance this anomaly. maybe web crawling? delete all rows that has price upper than / lower than some amount?
#
# Moreover, the prices of the most expensive cars are all same. Maybe this is an error and if it is, these rows should be removed.
#
# Plus, some car price are abnormaly low. 2 year old Jeep Gladiator Rubicon is about $3K, but the new one is $30K. down by -90% in 2 years? what happened? Huge accidents? Used as a collateral? - but I think this is absolutely possible compared to cases above, though it's not common.
#
# To investigate this further, I drew histograms for each model that has this abnormal price. Let's look at it:

# %%
# get all car model names in list, that has at least one row has price higher than 500000.as_integer_ratio

models = train[train['price'] > 500000]['model'].unique()

# draw seaborn histograms for eacn model

for model in models[:10]:
    df = train[train['model'] == model]
    print(len(df))
    sns.histplot(df['price'])
    plt.show()
# Out:
# 2945
# 168
# 70
# 1219
# 63
# 29
# 280
# 798
# 457
# 71

# %% [markdown]
# ... And definitely I can see abnormal prices. Guess I should omit all rows that has price over 2 sigma among the same model.

# %%
# print all unique context of transmission column with its count

unique_transmissions = train['transmission'].value_counts()

print(unique_transmissions)
# Out:
# A/T                                                   49904
# 8-Speed A/T                                           20645
# Transmission w/Dual Shift Mode                        19255
# 6-Speed A/T                                           18044
# 6-Speed M/T                                           11998
# 7-Speed A/T                                           11124
# Automatic                                             10691
# 8-Speed Automatic                                      8431
# 10-Speed A/T                                           8044
# 9-Speed A/T                                            3866
# 5-Speed A/T                                            3217
# 10-Speed Automatic                                     3164
# 6-Speed Automatic                                      2799
# 4-Speed A/T                                            2546
# 5-Speed M/T                                            2409
# 9-Speed Automatic                                      2325
# CVT Transmission                                       1990
# 1-Speed A/T                                            1869
# M/T                                                    1179
# 7-Speed Automatic with Auto-Shift                      1172
# Automatic CVT                                           829
# 8-Speed Automatic with Auto-Shift                       549
# 1-Speed Automatic                                       365
# 7-Speed M/T                                             355
# 6-Speed Manual                                          211
# 7-Speed Automatic                                       178
# 5-Speed Automatic                                       159
# Transmission Overdrive Switch                           156
# 7-Speed Manual                                          151
# 6-Speed Automatic with Auto-Shift                       111
# 2                                                        91
# –                                                        87
# 2-Speed A/T                                              71
# Variable                                                 66
# F                                                        65
# 4-Speed Automatic                                        48
# 10-Speed Automatic with Overdrive                        40
# 6 Speed Mt                                               37
# 9-Speed Automatic with Auto-Shift                        33
# 6-Speed Electronically Controlled Automatic with O       31
# 7-Speed                                                  29
# 8-Speed Manual                                           28
# Manual                                                   27
# 6-Speed                                                  27
# 2-Speed Automatic                                        22
# 6 Speed At/Mt                                            20
# 7-Speed DCT Automatic                                    18
# Single-Speed Fixed Gear                                  16
# CVT-F                                                    15
# 8-SPEED AT                                               13
# 8-SPEED A/T                                               7
# SCHEDULED FOR OR IN PRODUCTION                            6
# Name: transmission, dtype: int64

# %% [markdown]
# **Fact** : I can see a lot of (semi) duplicates in transmission column. For example, all '8-Speed Automatic', '8-Speed A/T', '8-SPEED A/T', and '8-SPEED AT indicates same thing, and same for 'A/T' and 'AT' / 'M/T' and 'MT', ... so on. Definitely need some cleansing.

# %%
print(train['ext_col'].value_counts())
print(train['int_col'].value_counts())
# Out:
# Black                                 48658
# White                                 43815
# Gray                                  25293
# Silver                                16995
# Blue                                  14555
#                                       ...
# GT SILVER                                 5
# Blue Caelum                               5
# Granite Crystal Metallic Clearcoat        5
# BLUE                                      3
# Mango Tango Pearlcoat                     2
# Name: ext_col, Length: 319, dtype: int64
# Black           107674
# Beige            24495
# Gray             21204
# Brown             5810
# Red               5145
#                  ...
# Nougat Brown         7
# Classic Red          7
# Cobalt Blue          6
# WHITE                6
# ORANGE               4
# Name: int_col, Length: 156, dtype: int64

# %% [markdown]
# **Fact**: A huge palette of 319/156 colors is shown, but most of them are a slight variation of few basic colors, so I think they can be aggergated into less then 10 categories. I will first drop all color features and (maybe) add later, after aggregating similar colors.

# %%
print(train['accident'].value_counts())
print(train['clean_title'].value_counts())
# Out:
# None reported                             144514
# At least 1 accident or damage reported     41567
# Name: accident, dtype: int64
# Yes    167114
# Name: clean_title, dtype: int64

# %%
print(train['transmission'].unique())
# Out:
# ['A/T' 'Transmission w/Dual Shift Mode' '7-Speed A/T' '8-Speed A/T'
#  '10-Speed Automatic' '1-Speed A/T' '6-Speed A/T' '10-Speed A/T'
#  '9-Speed A/T' '8-Speed Automatic' '9-Speed Automatic' '5-Speed A/T'
#  'Automatic' '7-Speed Automatic with Auto-Shift' 'CVT Transmission'
#  '5-Speed M/T' 'M/T' '6-Speed M/T' '6-Speed Automatic' '4-Speed Automatic'
#  '7-Speed M/T' '2-Speed A/T' '1-Speed Automatic' 'Automatic CVT'
#  '4-Speed A/T' '6-Speed Manual' 'Transmission Overdrive Switch'
#  '8-Speed Automatic with Auto-Shift' '7-Speed Manual' '7-Speed Automatic'
#  '9-Speed Automatic with Auto-Shift' '6-Speed Automatic with Auto-Shift'
#  '6-Speed Electronically Controlled Automatic with O' 'F' 'CVT-F'
#  '8-Speed Manual' 'Manual' '–' '2' '6 Speed At/Mt' '5-Speed Automatic'
#  '2-Speed Automatic' '8-SPEED A/T' '7-Speed' 'Variable'
#  'Single-Speed Fixed Gear' '8-SPEED AT'
#  '10-Speed Automatic with Overdrive' '7-Speed DCT Automatic'
#  'SCHEDULED FOR OR IN PRODUCTION' '6-Speed' '6 Speed Mt']

# %% [markdown]
# **Fact**: These columns are clean. Thank goodness.
#
# And finally the histograms and Box plots:

# %%
import seaborn as sns

for i in train.columns:
    if not (i == 'id' or i == 'model'):
        if train[i].dtype == 'object':
            sns.histplot(train[i].astype('str'))
            plt.show()
            continue
        sns.histplot(train[i])
        plt.show()
# Out:
# brand
# model_year
# milage
# fuel_type
# engine
# transmission
# ext_col
# int_col
# accident
# clean_title
# price
